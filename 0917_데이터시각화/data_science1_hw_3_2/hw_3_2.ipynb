# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.rcParams['font.family'] = 'Malgun Gothic'

# %%
#데이터 불러오기
file_path = 'data/category_data.csv'
df = pd.read_csv(file_path)

# %%
# 데이터 확인
print('== 상위 5개 행 출력 ==')
print(df.head())  # 상위 5개 행 출력
print()
print("== 데이터 타입 및 결측치 확인 ==")
print(df.info())  # 데이터 타입 및 결측치 확인
print()
print("== 기초 통계 확인 ==")
print(df.describe())  # 기초 통계 확인
# Out:
# == 상위 5개 행 출력 ==
#   Category  Value Subcategory
# 0        C     63           X
# 1        D     18           X
# 2        A     90           Y
# 3        C     44           Y
# 4        C     34           Y
#
# == 데이터 타입 및 결측치 확인 ==
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Category     100 non-null    object
#  1   Value        100 non-null    int64
#  2   Subcategory  100 non-null    object
# dtypes: int64(1), object(2)
# memory usage: 2.5+ KB
# None
#
# == 기초 통계 확인 ==
#            Value
# count  100.00000
# mean    49.75000
# std     29.45271
# min      1.00000
# 25%     26.75000
# 50%     46.00000
# 75%     77.25000
# max     99.00000

# %%
df['Category'].unique()
# Out:
# array(['C', 'D', 'A', 'B'], dtype=object)

# %%
# 1. 카테고리별 데이터 분포 시각화 (Bar Chart)

plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='Category', palette='viridis')  # 카테고리별 개수 시각화
plt.title('카테고리별 데이터 분포')
plt.xticks(rotation=45)  # X축 라벨 가독성 개선
plt.xlabel('카테고리')
plt.ylabel('개수')
plt.show()

# **해석**
# - 데이터가 각 카테고리에 어떻게 분포하는지 한눈에 파악할 수 있음.
# - 특정 카테고리에 데이터가 치우쳐 있거나 부족한 경우 데이터 수집 전략을 조정할 필요가 있음.
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_25824\2074983589.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Category', palette='viridis')  # 카테고리별 개수 시각화

# %% [markdown]
# sns.countplot ( data에는 데이터, x에는 x축에 들어갈 글자들(category)(짜피 data는 df인거 이미 넣었고 아니가 거기에 해당되는 열이름만 쓰면 됨), 그리고 뒤에는 팔레트... )

# %%
# 2. 카테고리별 수치 데이터 평균 비교 (Bar Chart)

if 'Value' in df.columns:  # '값' 컬럼이 존재하는 경우
    plt.figure(figsize=(12, 6))
    sns.barplot(data=df, x='Category', y='Value', estimator=sum, palette='coolwarm')
    
    plt.title('카테고리별 값 합계')
    plt.xticks(rotation=45)

    plt.xlabel('카테고리')
    plt.ylabel('합계 값')
    plt.show()

    # **해석**
    # - 각 카테고리에서 총합을 비교하여 상대적인 중요도를 파악 가능.
    # - 특정 카테고리의 값이 유난히 크거나 작은 경우 데이터 이상치를 검토해야 함.
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_25824\51218129.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df, x='Category', y='Value', estimator=sum, palette='coolwarm')

# %%
# 3. 카테고리별 분포 (Boxplot)

plt.figure(figsize=(12, 6))
sns.boxplot(data=df, x='Category', y='Value', palette='pastel')
plt.title('카테고리별 값 분포')
plt.xticks(rotation=45)
plt.xlabel('카테고리')
plt.ylabel('값')
plt.show()

# **해석**
# - 각 카테고리별 값의 중앙값, 범위 및 이상치를 시각적으로 확인할 수 있음.
# - 특정 카테고리에서 이상치가 많이 발견된다면 데이터 정제 작업이 필요할 수 있음.
# Out:
# C:\Users\SSAFY\AppData\Local\Temp\ipykernel_25824\338898056.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='Category', y='Value', palette='pastel')
