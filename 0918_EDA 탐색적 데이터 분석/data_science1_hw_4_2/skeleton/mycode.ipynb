# %%
# 포함 기술스택: python, pandas
import pandas as pd

# %%
# 데이터 로드
file_path = '../data/movie_data.csv'

movies = pd.read_csv(file_path)

# %%
movies
# Out:
#                        Title           Director  Year  Rating
# 0                       Jaws      James Cameron  1985     8.2
# 1                       E.T.   Steven Spielberg  2019     6.0
# 2              Jurassic Park   Steven Spielberg  2002     8.4
# 3           Schindler's List   Steven Spielberg  1999     8.7
# 4        Saving Private Ryan      James Cameron  1980     9.2
# 5              Indiana Jones   Steven Spielberg  1978     9.5
# 6        Catch Me If You Can  Christopher Nolan  1993     6.3
# 7            Minority Report  Christopher Nolan  2020     8.2
# 8          War of the Worlds      James Cameron  2009     8.3
# 9               The Terminal    Martin Scorsese  1999     6.9
# 10                  The Post      James Cameron  1973     6.8
# 11          Ready Player One    Martin Scorsese  2019     6.5
# 12                   Lincoln  Christopher Nolan  1997    10.0
# 13           Bridge of Spies    Martin Scorsese  2021     8.3
# 14                   The BFG  Quentin Tarantino  1986     9.0
# 15           West Side Story      James Cameron  1988     8.9
# 16                      Hook   Steven Spielberg  1991     9.7
# 17                   Amistad    Martin Scorsese  2004     9.9
# 18  The Adventures of Tintin      James Cameron  1989     8.6
# 19                 War Horse      James Cameron  1997     8.2
# 20                 Inception   Steven Spielberg  1979     7.2
# 21              Interstellar  Quentin Tarantino  1979     6.7
# 22                   Dunkirk    Martin Scorsese  2004     9.1
# 23                     Tenet    Martin Scorsese  1984     7.6
# 24                   Memento  Christopher Nolan  1991     7.6
# 25           The Dark Knight      James Cameron  2017     6.5
# 26              The Prestige   Steven Spielberg  1992     9.3
# 27              Pulp Fiction  Christopher Nolan  1989     7.5
# 28                 Kill Bill      James Cameron  2022     6.5
# 29          Django Unchained   Steven Spielberg  2022     6.2
# 30                    Avatar      James Cameron  1988     7.5
# 31                   Titanic   Steven Spielberg  2003     8.2
# 32            The Terminator   Steven Spielberg  1983     9.6
# 33                    Aliens   Steven Spielberg  2010     9.1
# 34                 True Lies  Christopher Nolan  2022    10.0

# %%
# 사용자로부터 감독 이름 입력 받기
director_name = input("감독의 이름을 입력하세요: ")

# %%
# 특정 감독의 영화 필터링
director_movies = movies.loc[movies['Director'] == director_name]

# %%
# 평균 평점 계산
average_rating = director_movies['Rating'].mean()
print(f"{director_name} 감독 영화의 평균 평점: {average_rating:.2f}")
# Out:
# James Cameron 감독 영화의 평균 평점: 7.87

# %%
# 가장 높은 평점을 받은 영화 찾기
best_movie = director_movies.loc[director_movies['Rating'].idxmax()]
print(f"가장 높은 평점을 받은 영화: {best_movie['Title']} ({best_movie['Rating']})")
# Out:
# 가장 높은 평점을 받은 영화: Saving Private Ryan (9.2)
